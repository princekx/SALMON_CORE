# %%
import iris
import os, sys
import warnings
import numpy as np
import datetime
# Set the global warning filter to ignore all warnings
warnings.simplefilter("ignore")

# %%
forecast_files = ['/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T006.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T012.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T018.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T024.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T030.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T036.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T042.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T048.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T054.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T060.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T066.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T072.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T078.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T084.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T090.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T096.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T102.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T108.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T114.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T120.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T126.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T132.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T138.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T144.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T150.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T156.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T162.pp', '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T168.pp']

# %%
forecast_files
# Out:
# ['/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T006.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T012.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T018.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T024.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T030.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T036.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T042.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T048.pp',
#  '/data/scratch/prince.xavier/SALMON/raw_data/mogreps/mogreps_bucket/20250102/00/000/qg00T054.pp',
# ...

# %%
168/24
# Out:
# 7.0

# %%
date = datetime.datetime(2025, 1, 1, 0)
forecast_cubes = []
for forecast_file in forecast_files:
    forecast_cube = iris.load_cube(forecast_file, 'x_wind')
    if len(forecast_cube.shape) == 4:
        forecast_cube = forecast_cube.collapsed('time', iris.analysis.MEAN)
        print(forecast_cube.coord('time').points)
    else:
        print(forecast_cube.coord('time').points)

    forecast_cube.cell_methods = ()
    if forecast_cube.coords("forecast_period"):  # If missing
        forecast_cube.remove_coord("forecast_period")
    forecast_period_coord = iris.coords.AuxCoord(
        np.array([(i+1)*6]), standard_name="forecast_period", units=f"hours since {date.strftime('%Y-%m-%d %H:00:00')}")
    forecast_cube.add_aux_coord(forecast_period_coord)
        
    if cube.coords("time"):  # If missing
        cube.remove_coord("time")
    
    forecast_time_coord = iris.coords.AuxCoord(
        np.array([(i+1)*6]), standard_name="time", units=f"hours since {date.strftime('%Y-%m-%d %H:00:00')}")
    cube.add_aux_coord(forecast_time_coord)
        
    if cube.coords("time"):
        print(f"Cube {i} forecast_period: {cube.coord('time').units}")
    else:
        print(f"Cube {i} has no time coordinate")
        
    forecast_cubes.append(forecast_cube)
# Out:
# [482165.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482171.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482177.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482183.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482189.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482195.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482201.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482207.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482213.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482220.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482226.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482232.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482238.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# [482244.]
# Cube 27 forecast_period: hours since 2025-01-01 00:00:00
# ...

# %%
for i, cube in enumerate(forecast_cubes):
    cube.cell_methods = ()
    print(f"Cube {i} cell methods: {cube.cell_methods}")
    #print(cube.coord('forecast_period').cell_method)
    #if cube.coord('time'):
    #    cube.remove_coord('time')
        #print(cube)
    if cube.coords("forecast_period"):  # If missing
        cube.remove_coord("forecast_period")
    forecast_period_coord = iris.coords.AuxCoord(
        np.array([(i+1)*6]), standard_name="forecast_period", units="hours"
    )
    cube.add_aux_coord(forecast_period_coord)
        
    if cube.coords("time"):  # If missing
        cube.remove_coord("time")
    
    forecast_time_coord = iris.coords.AuxCoord(
        np.array([(i+1)*6]), standard_name="time", units="hours since 2025-01-02 00:00:00")
    cube.add_aux_coord(forecast_time_coord)
        
    if cube.coords("time"):
        print(f"Cube {i} forecast_period: {cube.coord('time').units}")
    else:
        print(f"Cube {i} has no time coordinate")
iris.cube.CubeList(forecast_cubes).merge_cube()
# Out:
# Cube 0 cell methods: ()
# Cube 0 forecast_period: hours since 2025-01-02 00:00:00
# Cube 1 cell methods: ()
# Cube 1 forecast_period: hours since 2025-01-02 00:00:00
# Cube 2 cell methods: ()
# Cube 2 forecast_period: hours since 2025-01-02 00:00:00
# Cube 3 cell methods: ()
# Cube 3 forecast_period: hours since 2025-01-02 00:00:00
# Cube 4 cell methods: ()
# Cube 4 forecast_period: hours since 2025-01-02 00:00:00
# Cube 5 cell methods: ()
# Cube 5 forecast_period: hours since 2025-01-02 00:00:00
# Cube 6 cell methods: ()
# Cube 6 forecast_period: hours since 2025-01-02 00:00:00
# Cube 7 cell methods: ()
# Cube 7 forecast_period: hours since 2025-01-02 00:00:00
# Cube 8 cell methods: ()
# Cube 8 forecast_period: hours since 2025-01-02 00:00:00
# Cube 9 cell methods: ()
# Cube 9 forecast_period: hours since 2025-01-02 00:00:00
# Cube 10 cell methods: ()
# Cube 10 forecast_period: hours since 2025-01-02 00:00:00
# Cube 11 cell methods: ()
# ...

# %%
iris.cube.CubeList(forecast_cubes).merge_cube()
# Out:
# <iris 'Cube' of x_wind / (m s-1) (time: 28; pressure: 2; latitude: 961; longitude: 1280)>
