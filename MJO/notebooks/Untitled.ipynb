# %%
import datetime 
import iris

# %%
files = ['/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241013/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241014/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241015/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241016/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241017/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241018/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241019/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241020/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241021/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241022/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241023/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241024/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241025/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241026/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241027/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241028/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241029/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241030/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241031/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241101/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241102/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241103/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241104/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241105/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241106/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241107/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241108/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241109/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241110/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241111/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241112/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241113/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241114/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241115/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241116/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241117/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241118/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241119/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241120/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241121/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241122/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241123/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241124/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241125/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241126/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241127/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241128/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241129/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241130/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241201/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241202/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241203/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241204/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241205/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241206/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241207/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241208/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241209/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241210/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241211/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241212/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241213/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241214/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241215/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241216/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241217/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241218/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241219/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241220/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241221/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241222/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241223/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241224/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241225/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241226/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241227/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241228/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241229/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241230/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20241231/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250101/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250102/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250103/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250104/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250105/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250106/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250107/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250108/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250109/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250110/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250111/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250112/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250113/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250114/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250115/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250116/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250117/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250118/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250119/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250120/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250121/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250122/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250123/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250124/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250125/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250126/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250127/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250128/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250129/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250130/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250131/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250201/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250202/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250203/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250204/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250205/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250206/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250207/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250208/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250209/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250210/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250211/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250212/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250213/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250214/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250215/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250216/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250217/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250218/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250219/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250220/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250221/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250222/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250223/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250224/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250225/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250226/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250227/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250228/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250301/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250302/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250303/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250304/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250305/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250306/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250307/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250308/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250309/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250310/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250311/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250312/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250313/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250314/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250315/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250316/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250317/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250318/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250319/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250320/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250321/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250322/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250323/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250324/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250325/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250326/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250327/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250328/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250329/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250330/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250331/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250401/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250402/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250403/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250404/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250405/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250406/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250407/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250408/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250409/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250410/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250411/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250412/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250413/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250414/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250415/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250416/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250417/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250418/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250419/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250420/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250421/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250422/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250423/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250424/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250425/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250426/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250427/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250428/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250429/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250430/qg00T003.pp', '/data/scratch/prince.xavier/SALMON/raw_data/analysis/analysis_bucket/20250501/qg00T003.pp']

# %%
len(files)
# Out:
# 201

# %%
def remove_um_version(cube, field, filename):
    """Callback to remove the 'um_version' attribute."""
    if len(cube.coord('forecast_period').points) > 1:
        cube = cube.collapsed('forecast_period', iris.analysis.MEAN)
    cube.attributes.pop('um_version', None)

# %%
cubes = iris.load_cube(files, iris.Constraint(name='toa_outgoing_longwave_flux'), callback=remove_um_version)

# %%
cubes.collapsed('forecast_period', iris.analysis.MEAN)
# Out:
# /data/apps/sss/environments/default-2024_11_26/lib/python3.12/site-packages/iris/coords.py:2171: IrisVagueMetadataWarning: Cannot check if coordinate is contiguous: Invalid operation for 'forecast_period', with 0 bound(s). Contiguous bounds are only defined for 1D coordinates with 2 bounds. Metadata may not be fully descriptive for 'forecast_period'. Ignoring bounds.
#   warnings.warn(
# /data/apps/sss/environments/default-2024_11_26/lib/python3.12/site-packages/iris/coords.py:2158: IrisVagueMetadataWarning: Collapsing a multi-dimensional coordinate. Metadata may not be fully descriptive for 'time'.
#   warnings.warn(
# <iris 'Cube' of toa_outgoing_longwave_flux / (W m-2) (forecast_reference_time: 201; latitude: 1920; longitude: 2560)>

# %%
cubes
# Out:
# [<iris 'Cube' of toa_outgoing_longwave_flux / (W m-2) (forecast_period: 3; forecast_reference_time: 179; latitude: 1920; longitude: 2560)>,
# <iris 'Cube' of toa_outgoing_longwave_flux / (W m-2) (forecast_period: 3; forecast_reference_time: 22; latitude: 1920; longitude: 2560)>]

# %%
iris.cube.CubeList(cubes).merge_cube()
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 iris.cube.CubeList(cubes).merge_cube()
#
# File /data/apps/sss/environments/default-2024_11_26/lib/python3.12/site-packages/iris/cube.py:417, in CubeList.merge_cube(self)
#     415 proto_cube = iris._merge.ProtoCube(self[0])
#     416 for c in self[1:]:
# --> 417     proto_cube.register(c, error_on_mismatch=True)
#     419 # Extract the merged cube from the ProtoCube.
#     420 (merged_cube,) = proto_cube.merge()
#
# File /data/apps/sss/environments/default-2024_11_26/lib/python3.12/site-packages/iris/_merge.py:1294, in ProtoCube.register(self, cube, error_on_mismatch)
#    1292 cube_signature = self._cube_signature
#    1293 other = self._build_signature(cube)
# -> 1294 match = cube_signature.match(other, error_on_mismatch)
#    1295 if match:
# ...
